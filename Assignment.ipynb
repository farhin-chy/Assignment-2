# %% [markdown]
# <a href="https://colab.research.google.com/github/farhin-chy/Assignment-2/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Dataset
X = np.array([1, 2, 3, 4, 5], dtype=float)  # size
y = np.array([150, 200, 250, 300, 350], dtype=float)  # price

# Initialize parameters
m = 0.0  # slope
b = 0.0  # intercept
lr = 0.01
epochs = 200

losses = []
accuracies = []

# Gradient Descent
for epoch in range(epochs):
    # Prediction
    y_pred = m * X + b

    # Error
    error = y_pred - y
    mse = np.mean(error**2)
    losses.append(mse)

    # Define accuracy (pseudo accuracy based on % error)
    accuracy = 100 - (np.mean(np.abs(error / y)) * 100)
    accuracies.append(accuracy)

    # Gradients
    dm = np.mean(2 * error * X)
    db = np.mean(2 * error)

    # Update parameters
    m -= lr * dm
    b -= lr * db

    if epoch % 20 == 0:
        print(f"Epoch {epoch}, Loss={mse:.4f}, Accuracy={accuracy:.2f}%")

print(f"\n✅ Final Model: price = {m:.2f}*size + {b:.2f}")

# ------------------ Plot 1: Epoch vs Accuracy ------------------
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), accuracies, label="Accuracy", color="green")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Epoch vs Accuracy for Linear Regression")
plt.legend()

# ------------------ Plot 2: Data vs Regression Line ------------------
plt.subplot(1, 2, 2)
plt.scatter(X, y, color="blue", label="Actual Data")
plt.plot(X, m * X + b, color="red", label="Regression Line")
plt.xlabel("House Size (X)")
plt.ylabel("Price (y)")
plt.title("House Size vs Price with Regression Line")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 0, Loss=67500.0000, Accuracy=0.00%
# Epoch 20, Loss=1018.9912, Accuracy=86.24%
# Epoch 40, Loss=888.7108, Accuracy=87.16%
# Epoch 60, Loss=776.1177, Accuracy=88.00%
# Epoch 80, Loss=677.7894, Accuracy=88.79%
# Epoch 100, Loss=591.9185, Accuracy=89.52%
# Epoch 120, Loss=516.9269, Accuracy=90.21%
# Epoch 140, Loss=451.4361, Accuracy=90.85%
# Epoch 160, Loss=394.2425, Accuracy=91.45%
# Epoch 180, Loss=344.2949, Accuracy=92.01%
#
# ✅ Final Model: price = 61.26*size + 59.36
